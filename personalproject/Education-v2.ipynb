# %%
import pandas as pd

# %%
location = "./usdaeducation.xls"
df = pd.read_excel(location)
df.head()
# Out:
#    FIPS Code State       Area name  2003 Rural-urban Continuum Code  \
# 0          0    US   United States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga County                              2.0
# 3       1003    AL  Baldwin County                              4.0
# 4       1005    AL  Barbour County                              6.0
#
#    2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    2013 Urban Influence Code  Less than a high school diploma, 1970  \
# 0                        NaN                             52373312.0
# ...

# %%
#creat new database with 3 states
df_states = df.iloc[[1, 106,122]]

# %%
df_states
# Out:
#      FIPS Code State Area name  2003 Rural-urban Continuum Code  \
# 1         1000    AL   Alabama                              NaN
# 106       4000    AZ   Arizona                              NaN
# 122       5000    AR  Arkansas                              NaN
#
#      2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 1                          NaN                              NaN
# 106                        NaN                              NaN
# 122                        NaN                              NaN
#
#      2013 Urban Influence Code  Less than a high school diploma, 1970  \
# 1                          NaN                              1062306.0
# 106                        NaN                               383873.0
# 122                        NaN                               635149.0
#
#      High school diploma only, 1970  Some college (1-3 years), 1970  \
# 1                          468269.0                        136287.0
# ...

# %%
df_Edu_Level = df_states[['State','Percent of adults with less than a high school diploma, 2013-17','Percent of adults with a high school diploma only, 2013-17','Percent of adults completing some college or associate\'s degree, 2013-17','Percent of adults with a bachelor\'s degree or higher, 2013-17']]
df_Edu_Level
# Out:
#     State  Percent of adults with less than a high school diploma, 2013-17  \
# 1      AL                                               14.7
# 106    AZ                                               13.5
# 122    AR                                               14.4
#
#      Percent of adults with a high school diploma only, 2013-17  \
# 1                                                 30.9
# 106                                               24.2
# 122                                               34.3
#
#      Percent of adults completing some college or associate's degree, 2013-17  \
# 1                                                 29.9
# 106                                               33.9
# 122                                               29.2
#
#      Percent of adults with a bachelor's degree or higher, 2013-17
# 1                                                 24.5
# 106                                               28.4
# ...

# %%
location = "./usdaunemployment.xls"
df_unemploy = pd.read_excel(location)
df_unemploy.head()
# Out:
#    FIPStxt State           Area_name  Rural_urban_continuum_code_2013  \
# 0        0    US       United States                              NaN
# 1     1000    AL             Alabama                              NaN
# 2     1001    AL  Autauga County, AL                              2.0
# 3     1003    AL  Baldwin County, AL                              3.0
# 4     1005    AL  Barbour County, AL                              6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 0                        NaN         NaN                152191093.0
# 1                        NaN         NaN                  2175612.0
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 0    145156134.0        7034959.0                     4.6
# ...

# %%
df_Unemploy_by_yr = df_unemploy[['FIPStxt','State','Unemployment_rate_2013','Unemployment_rate_2014','Unemployment_rate_2015','Unemployment_rate_2016','Unemployment_rate_2017']]
df_Unemploy_by_yr
# Out:
#       FIPStxt State  Unemployment_rate_2013  Unemployment_rate_2014  \
# 0           0    US                     7.4                     6.2
# 1        1000    AL                     7.2                     6.8
# 2        1001    AL                     6.2                     5.8
# 3        1003    AL                     6.6                     6.1
# 4        1005    AL                    10.2                    10.5
# 5        1007    AL                     7.9                     7.2
# 6        1009    AL                     6.3                     6.1
# 7        1011    AL                     9.4                     8.8
# 8        1013    AL                    10.3                     8.5
# 9        1015    AL                     8.8                     8.0
# 10       1017    AL                     8.0                     6.7
# 11       1019    AL                     6.6                     5.8
# 12       1021    AL                     6.6                     6.3
# ...

# %%
#creat new database with 3 states
df_states_unemploy = df_Unemploy_by_yr.iloc[[1, 102,118]]
df_states_unemploy
# Out:
#      FIPStxt State  Unemployment_rate_2013  Unemployment_rate_2014  \
# 1       1000    AL                     7.2                     6.8
# 102     4000    AZ                     7.7                     6.8
# 118     5000    AR                     7.2                     6.0
#
#      Unemployment_rate_2015  Unemployment_rate_2016  Unemployment_rate_2017
# 1                       6.1                     5.9                     4.4
# 102                     6.1                     5.4                     4.9
# 118                     5.0                     3.9                     3.7

# %%
Col_Names=df_states_unemploy.iloc[:,2:]
# by putting a : at the begining, in [:] - it references the row

# %%
Col_Str=' + '.join(Col_Names)
Col_Str
# Out:
# 'Unemployment_rate_2013 + Unemployment_rate_2014 + Unemployment_rate_2015 + Unemployment_rate_2016 + Unemployment_rate_2017'

# %%
df_states_unemploy['mean']=df_states_unemploy.eval(Col_Str)/len(df_states_unemploy.columns)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_states_unemploy.head()
# Out:
#      FIPStxt State  Unemployment_rate_2013  Unemployment_rate_2014  \
# 1       1000    AL                     7.2                     6.8
# 102     4000    AZ                     7.7                     6.8
# 118     5000    AR                     7.2                     6.0
#
#      Unemployment_rate_2015  Unemployment_rate_2016  Unemployment_rate_2017  \
# 1                       6.1                     5.9                     4.4
# 102                     6.1                     5.4                     4.9
# 118                     5.0                     3.9                     3.7
#
#          mean
# 1    4.342857
# 102  4.414286
# 118  3.685714
