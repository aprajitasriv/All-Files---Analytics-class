# %%
import pandas as pd

# %%
location = "./usdapopulation.xls"
df = pd.read_excel(location)
df.head()
# Out:
#    FIPS State       Area_Name  Rural-urban_Continuum Code_2003  \
# 0     0    US   United States                              NaN
# 1  1000    AL         Alabama                              NaN
# 2  1001    AL  Autauga County                              2.0
# 3  1003    AL  Baldwin County                              4.0
# 4  1005    AL  Barbour County                              6.0
#
#    Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              2.0                        2.0
# 3                              3.0                        5.0
# 4                              6.0                        6.0
#
#    Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP  \
# 0                        NaN                     NaN        308745538
# ...

# %%
df_county = df['Area_Name']

# %%
df_county.head()
# Out:
# 0     United States
# 1           Alabama
# 2    Autauga County
# 3    Baldwin County
# 4    Barbour County
# Name: Area_Name, dtype: object

# %%
import nltk 
from nltk.probability import FreqDist

# %%
fd_county = FreqDist(df_county) #This function gives the frequency

# %%
fd_county
# Out:
# FreqDist({'United States': 1,
#           'Alabama': 1,
#           'Autauga County': 1,
#           'Baldwin County': 2,
#           'Barbour County': 2,
#           'Bibb County': 2,
#           'Blount County': 2,
#           'Bullock County': 1,
#           'Butler County': 8,
#           'Calhoun County': 11,
#           'Chambers County': 2,
#           'Cherokee County': 8,
#           'Chilton County': 1,
#           'Choctaw County': 3,
#           'Clarke County': 5,
#           'Clay County': 18,
#           'Cleburne County': 2,
#           'Coffee County': 3,
#           'Colbert County': 1,
#           'Conecuh County': 1,
#           'Coosa County': 1,
#           'Covington County': 2,
#           'Crenshaw County': 1,
#           'Cullman County': 1,
#           'Dale County': 1,
#           'Dallas County': 5,
#           'DeKalb County': 6,
#           'Elmore County': 2,
#           'Escambia County': 2,
#           'Etowah County': 1,
# ...

# %%
import matplotlib.pyplot as plt

from wordcloud import WordCloud

# %%
wordcloud = WordCloud(background_color = 'white').generate_from_frequencies(fd_county)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import seaborn as sns
import matplotlib 
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['FIPS', 'State', 'Area_Name', 'Rural-urban_Continuum Code_2003',
#        'Rural-urban_Continuum Code_2013', 'Urban_Influence_Code_2003',
#        'Urban_Influence_Code_2013', 'Economic_typology_2015',
#        'CENSUS_2010_POP', 'ESTIMATES_BASE_2010',
#        ...
#        'R_DOMESTIC_MIG_2015', 'R_DOMESTIC_MIG_2016', 'R_DOMESTIC_MIG_2017',
#        'R_NET_MIG_2011', 'R_NET_MIG_2012', 'R_NET_MIG_2013', 'R_NET_MIG_2014',
#        'R_NET_MIG_2015', 'R_NET_MIG_2016', 'R_NET_MIG_2017'],
#       dtype='object', length=133)

# %%
df = df.drop([0])

# %%
sns.lmplot(x='FIPS', y='CENSUS_2010_POP', data=df)

# %%
#creat new database with 5 states
df_states = df.iloc[[0, 68, 98, 114, 190]]

# %%
df_states
# Out:
#      FIPS State   Area_Name  Rural-urban_Continuum Code_2003  \
# 1    1000    AL     Alabama                              NaN
# 69   2000    AK      Alaska                              NaN
# 99   4000    AZ     Arizona                              NaN
# 115  5000    AR    Arkansas                              NaN
# 191  6000    CA  California                              NaN
#
#      Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 1                                NaN                        NaN
# 69                               NaN                        NaN
# 99                               NaN                        NaN
# 115                              NaN                        NaN
# 191                              NaN                        NaN
#
#      Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP  \
# 1                          NaN                     NaN          4779736
# ...

# %%
sns.lmplot(x='FIPS', y='CENSUS_2010_POP', data=df_states)

# %%
sns.boxplot(data=df_states)

# %%
df_states = df[['POP_ESTIMATE_2013', 'POP_ESTIMATE_2014', 'POP_ESTIMATE_2015', 'POP_ESTIMATE_2016', 'POP_ESTIMATE_2017']]

# %%
df_states
# Out:
#       POP_ESTIMATE_2013  POP_ESTIMATE_2014  POP_ESTIMATE_2015  \
# 1               4827660            4840037            4850858
# 2                 54695              54864              54838
# 3                194736             199064             202863
# 4                 26947              26749              26264
# 5                 22503              22533              22561
# 6                 57623              57546              57590
# 7                 10549              10673              10419
# 8                 20372              20327              20141
# 9                116482             115941             115505
# 10                34122              33948              33968
# 11                26014              25897              25741
# 12                43645              43779              43706
# 13                13396              13318              13231
# 14                25118              24865              24708
# ...

# %%
df_states_New = df[['State', 'POP_ESTIMATE_2013', 'POP_ESTIMATE_2014', 'POP_ESTIMATE_2015', 'POP_ESTIMATE_2016', 'POP_ESTIMATE_2017']]

# %%
df_states
# Out:
#       POP_ESTIMATE_2013  POP_ESTIMATE_2014  POP_ESTIMATE_2015  \
# 1               4827660            4840037            4850858
# 2                 54695              54864              54838
# 3                194736             199064             202863
# 4                 26947              26749              26264
# 5                 22503              22533              22561
# 6                 57623              57546              57590
# 7                 10549              10673              10419
# 8                 20372              20327              20141
# 9                116482             115941             115505
# 10                34122              33948              33968
# 11                26014              25897              25741
# 12                43645              43779              43706
# 13                13396              13318              13231
# 14                25118              24865              24708
# ...

# %%
df_mystates = df_states_New.iloc[[0, 98, 114]]

# %%
sns.boxplot(data=df_mystates)
plt.xticks(rotation=-45)
plt.xlabel("Year")
plt.ylabel("Population")
# Out:
# Text(0,0.5,'Population')

# %%
df_mystates.describe()
# Out:
#        POP_ESTIMATE_2013  POP_ESTIMATE_2014  POP_ESTIMATE_2015  \
# count       3.000000e+00       3.000000e+00       3.000000e+00
# mean        4.800188e+06       4.837091e+06       4.876249e+06
# std         1.829827e+06       1.870819e+06       1.913444e+06
# min         2.956780e+06       2.964800e+06       2.975626e+06
# 25%         3.892220e+06       3.902418e+06       3.913242e+06
# 50%         4.827660e+06       4.840037e+06       4.850858e+06
# 75%         5.721892e+06       5.773236e+06       5.826560e+06
# max         6.616124e+06       6.706435e+06       6.802262e+06
#
#        POP_ESTIMATE_2016  POP_ESTIMATE_2017
# count       3.000000e+00       3.000000e+00
# mean        4.919139e+06       4.965099e+06
# std         1.960862e+06       2.007521e+06
# min         2.988231e+06       3.004279e+06
# 25%         3.924388e+06       3.939513e+06
# 50%         4.860545e+06       4.874747e+06
# 75%         5.884594e+06       5.945508e+06
# ...

# %%
df_mystates.columns
# Out:
# Index(['State', 'POP_ESTIMATE_2013', 'POP_ESTIMATE_2014', 'POP_ESTIMATE_2015',
#        'POP_ESTIMATE_2016', 'POP_ESTIMATE_2017'],
#       dtype='object')

# %%
plt.subplots(figsize=(13, 7))
sns.violinplot(x='State', y='POP_ESTIMATE_2010', data=df_states_New)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-c706330cbb7a> in <module>()
#       1 plt.subplots(figsize=(13, 7))
# ----> 2 sns.violinplot(x='State', y='POP_ESTIMATE_2010', data=df_states_New)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2343                              bw, cut, scale, scale_hue, gridsize,
#    2344                              width, inner, split, dodge, orient, linewidth,
# -> 2345                              color, palette, saturation)
#    2346
#    2347     if ax is None:
#
# ...

# %%
df_mystates

# %%
plt.subplots(figsize=(13, 7))
sns.violinplot(x='State', y='POP_ESTIMATE_2010', data=df_mystates)

# %%
import numpy as np

# %%
df_AL_Counties = df.iloc[1:68]

# %%
df_AL_Counties

# %%
df_al = df_AL_Counties[['State', 'Area_Name', 'ESTIMATES_BASE_2010']]

# %%
df_AZ_Counties = df.iloc[99:114]

# %%
df_AZ_Counties

# %%
df_az = df_AZ_Counties[['State', 'Area_Name', 'ESTIMATES_BASE_2010']]

# %%
df_az

# %%
df_AR_Counties = df.iloc[115:190]

# %%
df_AR_Counties

# %%
df_ar = df_AR_Counties[['State', 'Area_Name', 'ESTIMATES_BASE_2010']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-0264a25d7cdb> in <module>()
# ----> 1 df_ar = df_AR_Counties[['State', 'Area_Name', 'ESTIMATES_BASE_2010']]
#
# NameError: name 'df_AR_Counties' is not defined

# %%
df_ar
# Out:
#     State           Area_Name  ESTIMATES_BASE_2010
# 116    AR     Arkansas County                19015
# 117    AR       Ashley County                21851
# 118    AR       Baxter County                41513
# 119    AR       Benton County               221364
# 120    AR        Boone County                36910
# 121    AR      Bradley County                11505
# 122    AR      Calhoun County                 5368
# 123    AR      Carroll County                27445
# 124    AR       Chicot County                11800
# 125    AR        Clark County                22993
# 126    AR         Clay County                16083
# 127    AR     Cleburne County                25981
# 128    AR    Cleveland County                 8692
# 129    AR     Columbia County                24552
# 130    AR       Conway County                21267
# 131    AR    Craighead County                96443
# 132    AR     Crawford County                61949
# ...

# %%
df_counties = pd.concat([df_al, df_az, df_ar])

# %%
df_counties
# Out:
#     State           Area_Name  ESTIMATES_BASE_2010
# 2      AL      Autauga County                54571
# 3      AL      Baldwin County               182265
# 4      AL      Barbour County                27457
# 5      AL         Bibb County                22919
# 6      AL       Blount County                57324
# 7      AL      Bullock County                10911
# 8      AL       Butler County                20946
# 9      AL      Calhoun County               118586
# 10     AL     Chambers County                34170
# 11     AL     Cherokee County                25988
# 12     AL      Chilton County                43631
# 13     AL      Choctaw County                13858
# 14     AL       Clarke County                25833
# 15     AL         Clay County                13932
# 16     AL     Cleburne County                14972
# 17     AL       Coffee County                49948
# 18     AL      Colbert County                54428
# ...

# %%
plt.subplots(figsize=(13, 7))
sns.violinplot(x='State', y='ESTIMATES_BASE_2010', data=df_counties, scale = "width")

# %%
df_counties[df_counties['State'] == 'AZ'].min()
# Out:
# State                             AZ
# Area_Name              Apache County
# ESTIMATES_BASE_2010             8437
# dtype: object

# %%
plt.subplots(figsize=(10, 6))
sns.swarmplot(x='State', y='ESTIMATES_BASE_2010', data = df_counties)

# %%
sns.distplot(df_counties['ESTIMATES_BASE_2010'])

# %%
melt_df = pd.melt(df_mystates,
                 id_vars=['State'], #keep only the column name that will not be merged
                 var_name='pop') #all population columns were merged into this new column called rows. value now contains populations

melt_df.head()
# Out:
#   State                pop    value
# 0    AL  POP_ESTIMATE_2010  4785579
# 1    AZ  POP_ESTIMATE_2010  6407002
# 2    AR  POP_ESTIMATE_2010  2921737
# 3    AL  POP_ESTIMATE_2011  4798649
# 4    AZ  POP_ESTIMATE_2011  6465488

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x='pop', y='value',
             data=melt_df,
             hue='State')
