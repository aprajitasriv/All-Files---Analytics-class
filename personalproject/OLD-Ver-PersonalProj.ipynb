# %%
import pandas as pd

# %%
location = "./usdapopulation.xls"
df = pd.read_excel(location)
df.head()
# Out:
#    FIPS State       Area_Name  Rural-urban_Continuum Code_2003  \
# 0     0    US   United States                              NaN
# 1  1000    AL         Alabama                              NaN
# 2  1001    AL  Autauga County                              2.0
# 3  1003    AL  Baldwin County                              4.0
# 4  1005    AL  Barbour County                              6.0
#
#    Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              2.0                        2.0
# 3                              3.0                        5.0
# 4                              6.0                        6.0
#
#    Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP  \
# 0                        NaN                     NaN        308745538
# ...

# %%
df_county = df['Area_Name']

# %%
df_county.head()
# Out:
# 0     United States
# 1           Alabama
# 2    Autauga County
# 3    Baldwin County
# 4    Barbour County
# Name: Area_Name, dtype: object

# %%
import nltk 
from nltk.probability import FreqDist

# %%
fd_county = FreqDist(df_county) #This function gives the frequency

# %%
fd_county
# Out:
# FreqDist({'United States': 1,
#           'Alabama': 1,
#           'Autauga County': 1,
#           'Baldwin County': 2,
#           'Barbour County': 2,
#           'Bibb County': 2,
#           'Blount County': 2,
#           'Bullock County': 1,
#           'Butler County': 8,
#           'Calhoun County': 11,
#           'Chambers County': 2,
#           'Cherokee County': 8,
#           'Chilton County': 1,
#           'Choctaw County': 3,
#           'Clarke County': 5,
#           'Clay County': 18,
#           'Cleburne County': 2,
#           'Coffee County': 3,
#           'Colbert County': 1,
#           'Conecuh County': 1,
#           'Coosa County': 1,
#           'Covington County': 2,
#           'Crenshaw County': 1,
#           'Cullman County': 1,
#           'Dale County': 1,
#           'Dallas County': 5,
#           'DeKalb County': 6,
#           'Elmore County': 2,
#           'Escambia County': 2,
#           'Etowah County': 1,
# ...

# %%
import matplotlib.pyplot as plt

from wordcloud import WordCloud

# %%
wordcloud = WordCloud(background_color = 'white').generate_from_frequencies(fd_county)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import seaborn as sns
import matplotlib 
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['FIPS', 'State', 'Area_Name', 'Rural-urban_Continuum Code_2003',
#        'Rural-urban_Continuum Code_2013', 'Urban_Influence_Code_2003',
#        'Urban_Influence_Code_2013', 'Economic_typology_2015',
#        'CENSUS_2010_POP', 'ESTIMATES_BASE_2010',
#        ...
#        'R_DOMESTIC_MIG_2015', 'R_DOMESTIC_MIG_2016', 'R_DOMESTIC_MIG_2017',
#        'R_NET_MIG_2011', 'R_NET_MIG_2012', 'R_NET_MIG_2013', 'R_NET_MIG_2014',
#        'R_NET_MIG_2015', 'R_NET_MIG_2016', 'R_NET_MIG_2017'],
#       dtype='object', length=133)

# %%
df = df.drop([0])

# %%
sns.lmplot(x='FIPS', y='CENSUS_2010_POP', data=df)

# %%
#creat new database with 5 states
df_states = df.iloc[[0, 68, 98, 114, 190]]

# %%
df_states
# Out:
#      FIPS State   Area_Name  Rural-urban_Continuum Code_2003  \
# 1    1000    AL     Alabama                              NaN
# 69   2000    AK      Alaska                              NaN
# 99   4000    AZ     Arizona                              NaN
# 115  5000    AR    Arkansas                              NaN
# 191  6000    CA  California                              NaN
#
#      Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 1                                NaN                        NaN
# 69                               NaN                        NaN
# 99                               NaN                        NaN
# 115                              NaN                        NaN
# 191                              NaN                        NaN
#
#      Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP  \
# 1                          NaN                     NaN          4779736
# ...

# %%
sns.lmplot(x='FIPS', y='CENSUS_2010_POP', data=df_states)

# %%
sns.boxplot(data=df_states)

# %%
df_states = df[['POP_ESTIMATE_2010', 'POP_ESTIMATE_201​f_states = df[['POP_ESTIMATE_2010', 'POP_ESTIMATE_2011', 'POP_ESTIMATE_2012', 'POP_ESTIMATE_2013', 'POP_ESTIMATE_2014']]1', 'POP_ESTIMATE_2012', 'POP_ESTIMATE_2013', 'POP_ESTIMATE_2014']]

# %%
df_states
# Out:
#       POP_ESTIMATE_2010  POP_ESTIMATE_2011  POP_ESTIMATE_2012  \
# 1               4785579            4798649            4813946
# 2                 54750              55199              54927
# 3                183110             186534             190048
# 4                 27332              27351              27175
# 5                 22872              22745              22658
# 6                 57381              57562              57595
# 7                 10880              10675              10612
# 8                 20944              20880              20688
# 9                118466             117785             117219
# 10                34122              34031              34092
# 11                25973              25993              25958
# 12                43661              43688              43601
# 13                13849              13607              13561
# 14                25765              25582              25152
# ...

# %%
df_states_New = df[['State', 'POP_ESTIMATE_2010', 'POP_ESTIMATE_2011', 'POP_ESTIMATE_2012', 'POP_ESTIMATE_2013', 'POP_ESTIMATE_2014']]

# %%
df_states
# Out:
#      FIPS State   Area_Name  Rural-urban_Continuum Code_2003  \
# 1    1000    AL     Alabama                              NaN
# 69   2000    AK      Alaska                              NaN
# 99   4000    AZ     Arizona                              NaN
# 115  5000    AR    Arkansas                              NaN
# 191  6000    CA  California                              NaN
#
#      Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 1                                NaN                        NaN
# 69                               NaN                        NaN
# 99                               NaN                        NaN
# 115                              NaN                        NaN
# 191                              NaN                        NaN
#
#      Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP  \
# 1                          NaN                     NaN          4779736
# ...

# %%
df_mystates = df_states_New.iloc[[1, 98, 113]]

# %%
sns.boxplot(data=df_mystates)
plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
df_mystates.describe()
# Out:
#        POP_ESTIMATE_2010  POP_ESTIMATE_2011  POP_ESTIMATE_2012  \
# count       3.000000e+00       3.000000e+00       3.000000e+00
# mean        2.219625e+06       2.241089e+06       2.267081e+06
# std         3.627073e+06       3.659179e+06       3.704834e+06
# min         5.475000e+04       5.519900e+04       5.492700e+04
# 25%         1.259370e+05       1.288900e+05       1.285160e+05
# 50%         1.971240e+05       2.025810e+05       2.021050e+05
# 75%         3.302063e+06       3.334034e+06       3.373158e+06
# max         6.407002e+06       6.465488e+06       6.544211e+06
#
#        POP_ESTIMATE_2013  POP_ESTIMATE_2014
# count       3.000000e+00       3.000000e+00
# mean        2.290876e+06       2.321446e+06
# std         3.746497e+06       3.798235e+06
# min         5.469500e+04       5.486400e+04
# 25%         1.282525e+05       1.289515e+05
# 50%         2.018100e+05       2.030390e+05
# 75%         3.408967e+06       3.454737e+06
# ...

# %%
df_mystates.columns
# Out:
# Index(['POP_ESTIMATE_2010', 'POP_ESTIMATE_2011', 'POP_ESTIMATE_2012',
#        'POP_ESTIMATE_2013', 'POP_ESTIMATE_2014'],
#       dtype='object')

# %%
plt.subplots(figsize=(13, 7))
sns.violinplot(x='State', y='POP_ESTIMATE_2010', data=df_states_New)

# %%
df_mystates
# Out:
#      POP_ESTIMATE_2010  POP_ESTIMATE_2011  POP_ESTIMATE_2012  \
# 2                54750              55199              54927
# 99             6407002            6465488            6544211
# 114             197124             202581             202105
#
#      POP_ESTIMATE_2013  POP_ESTIMATE_2014
# 2                54695              54864
# 99             6616124            6706435
# 114             201810             203039
